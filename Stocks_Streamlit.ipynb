# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import datetime as d

# %%
df = pd.read_csv('../yfinance_Project/Stock_L.csv')

# %%
df
# Out:
#       Unnamed: 0        Date         Close          High           Low  \
# 0              0  2025-01-02  10627.737305  10647.733047  10311.804568
# 1              1  2025-01-03  10591.744141  10783.703257  10525.758194
# 2              2  2025-01-06  10709.719727  10727.715895  10549.753786
# 3              3  2025-01-07  10665.728516  10711.718721  10523.758751
# 4              4  2025-01-08  10751.709961  10765.706980  10493.764901
# ...          ...         ...           ...           ...           ...
# 2785         274  2026-02-02     49.500000     53.000000     48.000000
# 2786         275  2026-02-03     56.500000     58.000000     49.000000
# 2787         276  2026-02-04     59.099998     63.000000     56.000000
# 2788         277  2026-02-05     60.000000     63.000000     57.000000
# 2789         278  2026-02-06     60.500000     62.000000     59.000000
#
#               Open   Volume            Stock
# 0     10403.784985  2588002  AstraZeneca plc
# 1     10653.730939  2879413  AstraZeneca plc
# 2     10549.753786  2451616  AstraZeneca plc
# 3     10595.743420  2763990  AstraZeneca plc
# 4     10661.729126  1222394  AstraZeneca plc
# ...            ...      ...              ...
# 2785     51.500000  1575019     Avacta Group
# 2786     50.000000  4352006     Avacta Group
# 2787     56.500000  3874225     Avacta Group
# 2788     59.000000  2189755     Avacta Group
# 2789     60.000000   742881     Avacta Group
#
# [2790 rows x 8 columns]

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#             Date         Close          High           Low          Open  \
# 0     2025-01-02  10627.737305  10647.733047  10311.804568  10403.784985
# 1     2025-01-03  10591.744141  10783.703257  10525.758194  10653.730939
# 2     2025-01-06  10709.719727  10727.715895  10549.753786  10549.753786
# 3     2025-01-07  10665.728516  10711.718721  10523.758751  10595.743420
# 4     2025-01-08  10751.709961  10765.706980  10493.764901  10661.729126
# ...          ...           ...           ...           ...           ...
# 2785  2026-02-02     49.500000     53.000000     48.000000     51.500000
# 2786  2026-02-03     56.500000     58.000000     49.000000     50.000000
# 2787  2026-02-04     59.099998     63.000000     56.000000     56.500000
# 2788  2026-02-05     60.000000     63.000000     57.000000     59.000000
# 2789  2026-02-06     60.500000     62.000000     59.000000     60.000000
#
#        Volume            Stock
# 0     2588002  AstraZeneca plc
# 1     2879413  AstraZeneca plc
# 2     2451616  AstraZeneca plc
# 3     2763990  AstraZeneca plc
# 4     1222394  AstraZeneca plc
# ...       ...              ...
# 2785  1575019     Avacta Group
# 2786  4352006     Avacta Group
# 2787  3874225     Avacta Group
# 2788  2189755     Avacta Group
# 2789   742881     Avacta Group
#
# [2790 rows x 7 columns]

# %%
df.Date = df.Date.astype('datetime64[ns]')

# %%
print(df.Stock.unique())
st= input("Enter Stock Name:")
r= df[df.Stock==st]
sb.lineplot(x = r.Date, y = r.Close)
plt.show()
# Out:
# ['AstraZeneca plc' 'GSK plc' 'HUTCHMED' 'Poolbeg Pharma' 'PureTech Health'
#  'Hikma Pharmaceuticals' 'Genus plc' 'Oxford Biomedica' 'Haleon PLC'
#  'Avacta Group']
# Enter Stock Name: GSK plc

# %%
sb.lineplot(x= r.Date, y=r.Close)
plt.show()
